# %% [markdown]
# ## Tipos de gráficos com matplotlib

# %% [markdown]
# ### Importa bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Carrega dados de chuvas

# %%
df = pd.read_csv("dados_chuvas_ficticias.csv", parse_dates=["data"])
print(df.head())
# Out:
#         data  temperatura_media  precipitacao_mm  umidade tipo_chuva
# 0 2024-01-01               34.4             49.4       57      Forte
# 1 2024-01-02               24.1             34.1       43    Nenhuma
# 2 2024-01-03               25.5             27.2       50      Fraca
# 3 2024-01-04               34.9             27.9       92      Fraca
# 4 2024-01-05               28.2             32.5       85   Moderada

# %% [markdown]
# #### Gráfico de colunas

# %% [markdown]
# Adequado para comparar quantidade entre diferentes categorias.

# %%
contagem_chuvas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 contagem_chuvas
#
# NameError: name 'contagem_chuvas' is not defined

# %%
contagem_chuvas = df["tipo_chuva"}.value_counts()
.sort_values(ascending=False)

plt.bar(contagem_chuvas.index, contagem_chuvas.values)
plt.title("Quantidade de dias por tipo de chuva")
plt.xlabel("Tipo de chuva")
plt.ylabel("Número de dias")
plt.show()
# Out:
#   Cell In[5], line 1
#     contagem_chuvas = df["tipo_chuva"}.value_counts()
#                                      ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %% [markdown]
# #### Gráfico de Linhas

# %% [markdown]
# Adequado para visualizar tendências e evoluções de sequências numéricas ao longo do tempo

# %%
plt.plot(df["data"], df["temperatura_media"])
plt.title("Evolução da temperatura média diária")
plt.xlabel("Data")
plt.ylabel("Temperatura °C")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Gráfico de pizza
# Adequado para representar proporções de um todo

# %%
plt.pie(contagem_chuvas.values, labels=contagem_chuvas.index)
plt.title("Distribuição dos tipos de chuva")

plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.pie(tipo_chuva.values, labels=contagem_chuvas.index)
#       2 plt.title("Distribuição dos tipos de chuva")
#       4 plt.show
#
# NameError: name 'tipo_chuva' is not defined

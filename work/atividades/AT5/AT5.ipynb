# %% [markdown]
# ### AT5 - Análise exploratória e visualização de dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Indicar a quantidade de linhas e colunas do dataset

# %%
print("Quantidade de linhas e colunas:")
print(df.shape)
# Out:
# Quantidade de linhas e colunas:
# (891, 12)

# %% [markdown]
# #### Indicar o tipo de dado de cada variável

# %%
print("Tipos de dados:")
print(df.dtypes)
# Out:
# Tipos de dados:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### Realizar um resumo estatístico das variáveis

# %%
print("Resumo estatístico:")
print(df.describe())
# Out:
# Resumo estatístico:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### Criar uma tabela de frequência e um gráfico pra a variável "survival". Explique a escolha do tipo de gráfico;

# %%
frequencia_survival.plot(
    kind="bar",
    figsize=(6,4)
)

plt.title("Quantidade de Sobreviventes")
plt.xlabel("Sobreviveu")
plt.ylabel("Quantidade")
plt.xticks([0,1], ["Não", "Sim"], rotation=0)

plt.show()

print("Foi utilizado um gráfico de barras porque a variável Survived é categórica.")
print("O gráfico facilita a comparação entre sobreviventes e não sobreviventes.")
# Out:
# Foi utilizado um gráfico de barras porque a variável Survived é categórica.
# O gráfico facilita a comparação entre sobreviventes e não sobreviventes.

# %% [markdown]
# #### Quantas pessoas sobreviveram? Qual a classe mais frequente?

# %%
sobreviventes = df["Survived"].sum()
print("Quantidade de sobreviventes: ", sobreviventes)

classe_frequente = df["Pclass"].mode()[0]
print("Classe mais frequente:", classe_frequente)
# Out:
# Quantidade de sobreviventes:  342
# Classe mais frequente: 3

# %% [markdown]
# #### Avalie a relação entre a variável "sex" e a variável "survival". Crie uma tabela de frequência e um gráfico. Mulheres sovreviveram mais que homes?

# %%
tabela_sex_survival.plot(
    kind="bar",
    figsize=(7,5)
)

plt.title("Relação entre Sexo e Sobrevivência")
plt.xlabel("Sexo")
plt.ylabel("Quantidade")
plt.xticks(rotation=0)

plt.legend(["Não sobreviveu", "Sobreviveu"])

plt.show()
print("As mulheres sobreviveram mais que os homens.")
# Out:
# As mulheres sobreviveram mais que os homens.

# %% [markdown]
# #### Qual é  distribuição das idades dos passageiros? Crie um gráfico para visualizar a distribuição. Parece simétrica? A maioria dos passageiros era jovem ou idosa?

# %%
df["Age"].plot(
    kind="hist",
    bins=20,
    figsize=(7,5)
)
print("A distribuição das idades não parece perfeitamente simétrica.")
print("A maioria dos passageiros era jovem/adulta.")
# Out:
# A distribuição das idades não parece perfeitamente simétrica.
# A maioria dos passageiros era jovem/adulta.
